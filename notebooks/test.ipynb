# %%
import sys

print(sys.executable)
print(sys.version)

# %%
# Smoke test
import duckdb
import fastapi
import geopandas
import httpx
import matplotlib
import numpy
import pandas
import pyarrow
import pydantic
import rasterio
import requests

print("Snakepit imports successfully.")
