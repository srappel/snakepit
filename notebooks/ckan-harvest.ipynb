# %%
import requests
import json
import pprint

# %%
packge_list_response = requests.get(
    "https://data.milwaukee.gov/api/3/action/package_search"
)
response_dict = json.loads(packge_list_response.content)

# %%
# Check the contents of the response.
assert response_dict["success"] is True
result = response_dict["result"]
pprint.pprint(result["results"][0])
# Out:
# {'author': '',
#  'author_email': '',
#  'creator_user_id': '329ddd5b-a076-40cf-a891-c1fb59ddb2b8',
#  'extras': [],
#  'groups': [],
#  'id': '1399bac2-cd16-49aa-9caa-a3d884b1210e',
#  'isopen': True,
#  'license_id': 'cc-by',
#  'license_title': 'Creative Commons Attribution',
#  'license_url': 'http://www.opendefinition.org/licenses/cc-by',
#  'maintainer': '',
#  'maintainer_email': '',
#  'metadata_created': '2019-08-01T20:30:08.711114',
#  'metadata_modified': '2026-08-17T09:51:52.960983',
#  'name': 'dataset-catalog',
#  'notes': 'This dataset is a catalog of all the datasets available on the City '
#           'of Milwaukee Open Data portal.',
#  'num_resources': 1,
#  'num_tags': 3,
#  'organization': {'approval_status': 'approved',
#                   'created': '2018-01-31T16:53:50.064659',
#                   'description': 'The City of Milwaukee uses information '
#                                  'systems to add value to the community by '
#                                  'delivering high quality services at the '
#                                  'lowest possible cost.\r\n'
#                                  '\r\n'
#                                  '#Mission Statement\r\n'
#                                  '\r\n'
#                                  "The Department of Administration's "
#                                  'Information and Technology Management '
#                                  'Division (ITMD) will lead the City in using '
#                                  'and sharing information in ways that will '
#                                  'provide the maximum efficiency and greatest '
#                                  "benefit to Milwaukee city's citizens, "
#                                  'businesses, and City government.',
#                   'id': 'fdbe00a1-ac18-493d-bda7-120dca01d2cb',
#                   'image_url': '2018-02-05-194758.323696ITMDLOGO.JPG',
#                   'is_organization': True,
#                   'name': 'information-technology-and-management-division',
#                   'state': 'active',
#                   'title': 'Information Technology and Management Division',
#                   'type': 'organization'},
#  'owner_org': 'fdbe00a1-ac18-493d-bda7-120dca01d2cb',
#  'private': False,
#  'relationships_as_object': [],
#  'relationships_as_subject': [],
#  'resources': [{'cache_last_updated': None,
#                 'cache_url': None,
#                 'created': '2019-12-14T02:16:21.493176',
#                 'datastore_active': True,
#                 'datastore_contains_all_records_of_source_file': False,
#                 'description': 'This dataset is a catalog of all the datasets '
#                                'available on the City of Milwaukee Open Data '
#                                'portal.',
#                 'format': 'CSV',
#                 'hash': '',
#                 'id': '9a4bf009-869f-49b7-81de-c03c386c433a',
#                 'last_modified': '2026-08-17T09:51:52.909862',
#                 'metadata_modified': '2026-08-17T09:51:52.970580',
#                 'mimetype': None,
#                 'mimetype_inner': None,
#                 'name': 'Dataset Catalog',
#                 'package_id': '1399bac2-cd16-49aa-9caa-a3d884b1210e',
#                 'position': 0,
#                 'resource_type': 'csv',
#                 'size': None,
#                 'state': 'active',
#                 'url': 'https://data.milwaukee.gov/datastore/dump/9a4bf009-869f-49b7-81de-c03c386c433a',
#                 'url_type': 'datastore'}],
#  'state': 'active',
#  'tags': [{'display_name': 'Datasets',
#            'id': '7cd8794a-75b6-413b-a1ce-5c7522667466',
#            'name': 'Datasets',
#            'state': 'active',
#            'vocabulary_id': None},
#           {'display_name': 'Inventory',
#            'id': '182a75b7-859b-474f-9419-8b8f9ae83599',
#            'name': 'Inventory',
#            'state': 'active',
#            'vocabulary_id': None},
#           {'display_name': 'List',
#            'id': '39c5349f-1047-40e0-bf88-cd5e2fb198c7',
#            'name': 'List',
#            'state': 'active',
#            'vocabulary_id': None}],
#  'title': 'City of Milwaukee Open Data Dataset Catalog',
#  'type': 'dataset',
#  'url': '',
#  'version': ''}
